# %%
import pandas as pd

# Load the LendingClub loan data (CSV file)
loan_df = pd.read_csv(r"C:\Users\rudhi\Downloads\IITM Hackathon\Lending Club\loan.csv")

# Load the data dictionary (if needed, only if it's an Excel file)
data_dict_df = pd.read_excel(r"C:\Users\rudhi\Downloads\IITM Hackathon\Lending Club\LCDataDictionary.xlsx")

# View the first few rows of the loan data
loan_df.head()
# Out:
# C:\Users\rudhi\AppData\Local\Temp\ipykernel_75308\639986610.py:4: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan_df = pd.read_csv(r"C:\Users\rudhi\Downloads\IITM Hackathon\Lending Club\loan.csv")
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       2500         2500           2500.0   36 months
# 1 NaN        NaN      30000        30000          30000.0   60 months
# 2 NaN        NaN       5000         5000           5000.0   36 months
# 3 NaN        NaN       4000         4000           4000.0   36 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.56        84.92     C        C1  ...                            NaN
# 1     18.94       777.23     D        D2  ...                            NaN
# ...

# %%
# Remove any duplicate rows in the dataset
loan_df = loan_df.drop_duplicates()

# %%
# Print the column names of the dataframe
# Save the column names to a text file
with open(r"C:\Users\rudhi\Downloads\IITM Hackathon\Lending Club\column_names.txt", "w") as f:
    for column in loan_df.columns:
        f.write(f"{column}\n")

# %%
import pandas as pd

# Load the LendingClub loan data (CSV file)
loan_df = pd.read_csv(r"C:\Users\rudhi\Downloads\IITM Hackathon\Lending Club\loan.csv")

# Checking for missing data
missing_data = loan_df.isnull().sum()

# For numerical features, fill missing values with the median
numerical_columns = loan_df.select_dtypes(include=['float64', 'int64']).columns
for col in numerical_columns:
    loan_df[col].fillna(loan_df[col].median(), inplace=True)

# For categorical features, fill missing values with 'Unknown'
categorical_columns = loan_df.select_dtypes(include=['object']).columns
for col in categorical_columns:
    loan_df[col].fillna('Unknown', inplace=True)

# Verify if there are any remaining missing values
missing_data_after = loan_df.isnull().sum()

# Display the first few rows of the cleaned data
loan_df.head()
# Out:
# C:\Users\rudhi\AppData\Local\Temp\ipykernel_75308\4027071411.py:4: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan_df = pd.read_csv(r"C:\Users\rudhi\Downloads\IITM Hackathon\Lending Club\loan.csv")
# c:\Users\rudhi\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\rudhi\AppData\Local\Temp\ipykernel_75308\4027071411.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Select only numeric columns
numeric_cols = loan_df.select_dtypes(include=['float64', 'int64']).columns

# Initialize the scaler
scaler = MinMaxScaler()

# Apply the scaler to numeric columns
loan_df[numeric_cols] = scaler.fit_transform(loan_df[numeric_cols])
# Out:
# c:\Users\rudhi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_array_api.py:701: RuntimeWarning: All-NaN slice encountered
#   return xp.asarray(numpy.nanmin(X, axis=axis))
# c:\Users\rudhi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_array_api.py:718: RuntimeWarning: All-NaN slice encountered
#   return xp.asarray(numpy.nanmax(X, axis=axis))

# %%
pip install tweepy
# Out:
# ...
#
# ...

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plaid-python
# Out:
# ...
#      ---------------------------------------- 0.0/994.0 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/994.0 kB ? eta -:--:--
#      -------------------------------------- 994.0/994.0 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for plaid-python: filename=plaid_python-28.0.0-py3-none-any.whl size=4990153 sha256=97e28c9705b09c0b200d6e89aff692479d4b7cfa079fb864740823188bc958b6
#   Stored in directory: c:\users\rudhi\appdata\local\pip\cache\wheels\d8\76\6f\2fbe63449c57635cafa039460d045dc4020c707a7ab8218be3
# Successfully built plaid-python
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy

# Set up the Tweepy API client for v2
client = tweepy.Client(
    consumer_key = 'Xxj5SgHGQxdnNpqgKmIMJ0oA5',
    consumer_secret = 'LK9P3nEk48I1pDjGw2D19qc6ntrkmUbxK8eEyQ8SW5xCKXqpgb',
    access_token = '1629496960267722757-qafSAfoUFQet5Igtj0IqJTiUsGcoHs',
    access_token_secret = 'HPsrjzbkZkAzSOq0D7LQUMnVb19mNbZHrkpK2UyEo2FR9'
)

# Fetch user details to get user_id
user_handle = 'borrower_social_handle'
user = client.get_user(username=user_handle)
user_id = user.data.id

# Fetch the user's tweets
tweets = client.get_users_tweets(user_id, max_results=100)

# Extract tweet texts
tweet_texts = [tweet.text for tweet in tweets.data]
print(tweet_texts)
# Out:
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# Cell In[16], line 13
#      11 # Fetch user details to get user_id
#      12 user_handle = 'borrower_social_handle'
# ---> 13 user = client.get_user(username=user_handle)
#      14 user_id = user.data.id
#      16 # Fetch the user's tweets
#
# File c:\Users\rudhi\AppData\Local\Programs\Python\Python311\Lib\site-packages\tweepy\client.py:2441, in Client.get_user(self, id, username, user_auth, **params)
#    2438 else:
#    2439     raise TypeError("ID or username is required")
# -> 2441 return self._make_request(
#    2442     "GET", route, params=params,
#    2443     endpoint_parameters=("expansions", "tweet.fields", "user.fields"),
#    2444     data_type=User, user_auth=user_auth
#    2445 )
#
# ...

# %%
consumer_key = 'Xxj5SgHGQxdnNpqgKmIMJ0oA5'
consumer_secret = 'LK9P3nEk48I1pDjGw2D19qc6ntrkmUbxK8eEyQ8SW5xCKXqpgb'
access_token = '1629496960267722757-qafSAfoUFQet5Igtj0IqJTiUsGcoHs'
access_token_secret = 'HPsrjzbkZkAzSOq0D7LQUMnVb19mNbZHrkpK2UyEo2FR9'
